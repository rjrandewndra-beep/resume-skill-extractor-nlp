# %% [markdown]
# # Model 1 - Logistic Regression
# Training and evaluating a Logistic Regression model for skill classification.

# %%
import pandas as pd
import numpy as np
print('Notebook initialized successfully!')
