# %% [markdown]
# # Model 2 - SVM
# Training and evaluating a Support Vector Machine (SVM) model for skill classification.

# %%
import pandas as pd
import numpy as np
print('Notebook initialized successfully!')
