# %% [markdown]
# # Model 3 - BERT
# Fine-tuning a BERT/Transformer model for advanced NER (Named Entity Recognition) to extract skills.

# %%
import pandas as pd
import numpy as np
print('Notebook initialized successfully!')
